# %% [markdown]
# # EC1: Warm-up problems

# %% [markdown]
# ## Problem 1

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import os
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import matplotlib
import seaborn as sns
# Apply the default theme
sns.set_theme()
matplotlib.rcParams['font.family'] = 'serif'
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Problem 2

# %% [markdown]
# Mount google drive where our data is

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# The link to the google drive is [link](https://drive.google.com/drive/folders/1iJ_qsyQ3OGcK06JryKeljqitTNMuiqN6?usp=share_link)

# %%
plt.plot(xs,ys)
plt.xscale('log')
